# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('drive/MyDrive/Colab Notebooks/recomendasi system/Stunting_Dataset.csv')
df
# Out:
#       Gender  Age  Birth Weight  Birth Length  Body Weight  Body Length  \
# 0       Male   17           3.0            49         10.0         72.2
# 1     Female   11           2.9            49          2.9         65.0
# 2       Male   16           2.9            49          8.5         72.2
# 3       Male   31           2.8            49          6.4         63.0
# 4       Male   15           3.1            49         10.5         49.0
# ...      ...  ...           ...           ...          ...          ...
# 9995    Male   15           3.0            49          9.0         63.0
# 9996  Female   12           2.8            48          7.7         63.0
# 9997    Male   16           2.8            49          7.7         49.0
# 9998    Male   14           2.8            49         10.0         69.0
# 9999  Female   10           3.0            49          7.7         80.0
#
#      Breastfeeding Stunting
# 0               No       No
# 1               No      Yes
# 2               No      Yes
# 3               No      Yes
# 4               No      Yes
# ...            ...      ...
# 9995            No      Yes
# 9996            No       No
# 9997            No       No
# 9998            No      Yes
# 9999            No      Yes
#
# [10000 rows x 8 columns]

# %%
df.value_counts('Stunting')
# Out:
# Stunting
# Yes    7955
# No     2045
# Name: count, dtype: int64

# %%
Stunting = {
    'No' : 0,
    'Yes' : 1,
}

Gender = {
    'Female': 0,
    'Male' : 1,
}

df['Stunting'] = df['Stunting'].map(Stunting)
df['Gender'] = df['Gender'].map(Gender)
df
# Out:
#       Gender  Age  Birth Weight  Birth Length  Body Weight  Body Length  \
# 0          1   17           3.0            49         10.0         72.2
# 1          0   11           2.9            49          2.9         65.0
# 2          1   16           2.9            49          8.5         72.2
# 3          1   31           2.8            49          6.4         63.0
# 4          1   15           3.1            49         10.5         49.0
# ...      ...  ...           ...           ...          ...          ...
# 9995       1   15           3.0            49          9.0         63.0
# 9996       0   12           2.8            48          7.7         63.0
# 9997       1   16           2.8            49          7.7         49.0
# 9998       1   14           2.8            49         10.0         69.0
# 9999       0   10           3.0            49          7.7         80.0
#
#      Breastfeeding  Stunting
# 0               No         0
# 1               No         1
# 2               No         1
# 3               No         1
# 4               No         1
# ...            ...       ...
# 9995            No         1
# 9996            No         0
# 9997            No         0
# 9998            No         1
# 9999            No         1
#
# [10000 rows x 8 columns]

# %%
df['Protein_g'] = (((df['Body Length'] / 5) *  df['Stunting'] / 5) + (df['Age']*2))
df
# Out:
#       Gender  Age  Birth Weight  Birth Length  Body Weight  Body Length  \
# 0          1   17           3.0            49         10.0         72.2
# 1          0   11           2.9            49          2.9         65.0
# 2          1   16           2.9            49          8.5         72.2
# 3          1   31           2.8            49          6.4         63.0
# 4          1   15           3.1            49         10.5         49.0
# ...      ...  ...           ...           ...          ...          ...
# 9995       1   15           3.0            49          9.0         63.0
# 9996       0   12           2.8            48          7.7         63.0
# 9997       1   16           2.8            49          7.7         49.0
# 9998       1   14           2.8            49         10.0         69.0
# 9999       0   10           3.0            49          7.7         80.0
#
#      Breastfeeding  Stunting  Protein_g
# 0               No         0     34.000
# 1               No         1     24.600
# 2               No         1     34.888
# 3               No         1     64.520
# 4               No         1     31.960
# ...            ...       ...        ...
# 9995            No         1     32.520
# 9996            No         0     24.000
# 9997            No         0     32.000
# 9998            No         1     30.760
# 9999            No         1     23.200
#
# [10000 rows x 9 columns]

# %%
df['Energy_kcal'] = (((df['Body Length'] / 5) *  df['Stunting'] / 5)) + ((df['Age']+1)*65)
df
# Out:
#       Gender  Age  Birth Weight  Birth Length  Body Weight  Body Length  \
# 0          1   17           3.0            49         10.0         72.2
# 1          0   11           2.9            49          2.9         65.0
# 2          1   16           2.9            49          8.5         72.2
# 3          1   31           2.8            49          6.4         63.0
# 4          1   15           3.1            49         10.5         49.0
# ...      ...  ...           ...           ...          ...          ...
# 9995       1   15           3.0            49          9.0         63.0
# 9996       0   12           2.8            48          7.7         63.0
# 9997       1   16           2.8            49          7.7         49.0
# 9998       1   14           2.8            49         10.0         69.0
# 9999       0   10           3.0            49          7.7         80.0
#
#      Breastfeeding  Stunting  Protein_g  Energy_kcal
# 0               No         0     34.000     1170.000
# 1               No         1     24.600      782.600
# 2               No         1     34.888     1107.888
# 3               No         1     64.520     2082.520
# 4               No         1     31.960     1041.960
# ...            ...       ...        ...          ...
# 9995            No         1     32.520     1042.520
# 9996            No         0     24.000      845.000
# 9997            No         0     32.000     1105.000
# 9998            No         1     30.760      977.760
# 9999            No         1     23.200      718.200
#
# [10000 rows x 10 columns]

# %%
umur = df['Age'] <= 11

df.loc[umur].sort_values('Age')
# Out:
#       Gender  Age  Birth Weight  Birth Length  Body Weight  Body Length  \
# 7875       1    6           2.3            49          6.4         68.3
# 9575       1    6           2.3            50          6.4         68.3
# 1408       0    6           3.0            49          7.1         65.0
# 1412       1    6           2.3            50          6.4         68.3
# 6595       0    6           2.0            49          7.7         65.0
# ...      ...  ...           ...           ...          ...          ...
# 5237       1   11           3.1            48          7.2         69.0
# 5236       0   11           2.8            49          7.0         73.5
# 5235       1   11           2.3            49          8.0         68.3
# 5297       1   11           2.7            49          7.1         63.0
# 4974       1   11           3.0            49          7.7         65.0
#
#      Breastfeeding  Stunting  Protein_g  Energy_kcal
# 7875            No         0      12.00       455.00
# 9575            No         0      12.00       455.00
# 1408            No         1      14.60       457.60
# 1412            No         0      12.00       455.00
# 6595            No         1      14.60       457.60
# ...            ...       ...        ...          ...
# 5237            No         1      24.76       782.76
# 5236            No         1      24.94       782.94
# 5235            No         0      22.00       780.00
# 5297            No         1      24.52       782.52
# 4974            No         1      24.60       782.60
#
# [3827 rows x 10 columns]

# %%
df
# Out:
#       Gender  Age  Birth Weight  Birth Length  Body Weight  Body Length  \
# 0          1   17           3.0            49         10.0         72.2
# 1          0   11           2.9            49          2.9         65.0
# 2          1   16           2.9            49          8.5         72.2
# 3          1   31           2.8            49          6.4         63.0
# 4          1   15           3.1            49         10.5         49.0
# ...      ...  ...           ...           ...          ...          ...
# 9995       1   15           3.0            49          9.0         63.0
# 9996       0   12           2.8            48          7.7         63.0
# 9997       1   16           2.8            49          7.7         49.0
# 9998       1   14           2.8            49         10.0         69.0
# 9999       0   10           3.0            49          7.7         80.0
#
#      Breastfeeding  Stunting  Protein_g  Energy_kcal
# 0               No         0     34.000     1170.000
# 1               No         1     24.600      782.600
# 2               No         1     34.888     1107.888
# 3               No         1     64.520     2082.520
# 4               No         1     31.960     1041.960
# ...            ...       ...        ...          ...
# 9995            No         1     32.520     1042.520
# 9996            No         0     24.000      845.000
# 9997            No         0     32.000     1105.000
# 9998            No         1     30.760      977.760
# 9999            No         1     23.200      718.200
#
# [10000 rows x 10 columns]

# %%
food_df_new = pd.read_csv('drive/MyDrive/Colab Notebooks/recomendasi system/preprocessed_dataset.csv')
food_df = food_df_new.drop(['Jumlah Porsi', 'Takaran Porsi'], axis=1)
food_df = food_df.loc[:, ['Protein (g)', 'Kalori (kkal)']]
food_df
# Out:
#      Protein (g)  Kalori (kkal)
# 0           2.00          160.0
# 1           0.29           23.0
# 2           1.62          116.0
# 3           3.77          266.0
# 4           0.04            3.0
# ..           ...            ...
# 387         1.12           37.0
# 388         1.40           36.0
# 389         0.80           38.0
# 390         0.57           31.0
# 391         6.13           41.0
#
# [392 rows x 2 columns]

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.model_selection import train_test_split
X, y = train_test_split(food_df , shuffle=False, train_size=0.8)

# %%
X
# Out:
#      Protein (g)  Kalori (kkal)
# 0           2.00          160.0
# 1           0.29           23.0
# 2           1.62          116.0
# 3           3.77          266.0
# 4           0.04            3.0
# ..           ...            ...
# 308         1.80          100.0
# 309         2.32          149.0
# 310         1.87           87.0
# 311         2.43          109.0
# 312         1.95           92.0
#
# [313 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
prep_data=scaler.fit_transform(X.to_numpy())

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(metric='cosine',)
model.fit(prep_data)
# Out:
# NearestNeighbors(metric='cosine')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
transformer = FunctionTransformer(model.kneighbors,kw_args={'return_distance':False})
pipeline=Pipeline([('std_scaler',scaler),('NN',transformer)])

# %%
params={'n_neighbors':5,'return_distance':False}
# pipeline.get_params()
pipeline.set_params(NN__kw_args=params)
# Out:
# Pipeline(steps=[('std_scaler', StandardScaler()),
#                 ('NN',
#                  FunctionTransformer(func=<bound method KNeighborsMixin.kneighbors of NearestNeighbors(metric='cosine')>,
#                                      kw_args={'n_neighbors': 5,
#                                               'return_distance': False}))])

# %%
pred_idx = 3
input = y.iloc[pred_idx]
prediction = pipeline.transform([input])[0]
food_df_new.iloc[prediction]
# Out:
#      Unnamed: 0                    Nama     Kategori  Jumlah Porsi  \
# 216         221              Mie Gandum  Karbohidrat           100
# 267         276     Acar Mentimun Manis        Sayur           100
# 208         213         Makaroni Gandum  Karbohidrat           100
# 229         237          Spageti Gandum  Karbohidrat           100
# 2             2  Guacamole dengan Tomat  Buah Buahan           100
#
#     Takaran Porsi  Kalori (kkal)  Lemak (g)  Lemak Jenuh (g)  \
# 216      gram (g)          120.0       1.37            0.343
# 267      gram (g)          117.0       0.26            0.066
# 208      gram (g)          123.0       0.54            0.098
# 229      gram (g)          123.0       0.54            0.098
# 2        gram (g)          116.0       9.94            1.446
#
#      Lemak Tak Jenuh Ganda (g)  Lemak Tak Jenuh Tunggal (g)  Kolestrol (g)  \
# 216                      0.360                        0.363           32.0
# 267                      0.106                        0.004            0.0
# 208                      0.212                        0.075            0.0
# 229                      0.212                        0.075            0.0
# 2                        1.258                        6.625            0.0
#
#      Protein (g)  Karbohidrat (g)  Serat (g)  Gula (g)  Sodium (g)  Kalium (g)
# 216         5.31            23.49        3.9      0.19       158.0       140.0
# 267         0.37            31.81        1.1     14.63       939.0        32.0
# 208         5.30            26.38        2.8      0.80       234.0        44.0
# 229         5.30            26.38        4.5      0.80       234.0        44.0
# 2           1.62             7.64        4.9      1.37       201.0       393.0

# %%
y.iloc[pred_idx]
# Out:
# Protein (g)        2.11
# Kalori (kkal)    122.00
# Name: 316, dtype: float64

# %%
from google.colab import files

# %%
import pickle


filename = 'recommender_model.h5'
knnPickle = open(filename, 'wb')

# source, destination
pickle.dump(pipeline, knnPickle)

# close the file
knnPickle.close()

# %%
files.download('recommender_model.h5')

# %%
pipeline = pickle.load(open(filename, 'rb'))
dfs = pd.read_csv('drive/MyDrive/Colab Notebooks/recomendasi system/preprocessed_dataset.csv')
result = pipeline.transform([[1.82, 3]])[0]
dfs.iloc[result]
# Out:
#      Unnamed: 0                                         Nama Kategori  \
# 123         126  Daging dan Kulit Sayap Ayam (Ayam Pedaging)   Daging
# 277         286                                        Bayam    Sayur
# 202         207                                 Yogurt Polos     Susu
# 206         211                 Yogurt Polos (Rendah Lemak )     Susu
# 203         208                    Yogurt Polos Rendah Lemak     Susu
#
#      Jumlah Porsi                                      Takaran Porsi  \
# 123             1  sayap, tulang dihilangkan (hasil dari 450 g - ...
# 277           100                                           gram (g)
# 202           100                                           gram (g)
# 206           100                                           gram (g)
# 203           100                                           gram (g)
#
#      Kalori (kkal)  Lemak (g)  Lemak Jenuh (g)  Lemak Tak Jenuh Ganda (g)  \
# 123           64.0       4.63            1.299                      0.055
# 277           23.0       0.39            0.063                      0.165
# 202           63.0       1.55            1.000                      0.044
# 206           63.0       1.55            1.000                      0.044
# 203           63.0       1.55            1.000                      0.044
#
#      Lemak Tak Jenuh Tunggal (g)  Kolestrol (g)  Protein (g)  Karbohidrat (g)  \
# 123                        0.983          1.842         5.32             0.00
# 277                        0.010          0.000         2.86             3.63
# 202                        0.426          6.000         5.25             7.04
# 206                        0.426          6.000         5.25             7.04
# 203                        0.426          6.000         5.25             7.04
#
#      Serat (g)  Gula (g)  Sodium (g)  Kalium (g)
# 123       22.0      0.00         0.0        21.0
# 277        2.2      0.42        79.0       558.0
# 202        0.0      7.04        70.0       234.0
# 206        0.0      7.04        70.0       234.0
# 203        0.0      7.04        70.0       234.0
